# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("taxis")

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
payment_missing_percent = df['payment'].isna().sum()/df.shape[0] * 100
pickup_zone_missing_percent = df['pickup_zone'].isna().sum()/df.shape[0] * 100
dropoff_zone_missing_percent = df['dropoff_zone'].isna().sum()/df.shape[0] * 100
pickup_borough_missing_percent = df['pickup_borough'].isna().sum()/df.shape[0] * 100
dropoff_borough_missing_percent = df['dropoff_borough'].isna().sum()/df.shape[0] * 100

# %%
df[['distance', 'fare', 'tip', 'tolls', 'total']].describe()
# Out:
#           distance         fare         tip        tolls        total
# count  6433.000000  6433.000000  6433.00000  6433.000000  6433.000000
# mean      3.024617    13.091073     1.97922     0.325273    18.517794
# std       3.827867    11.551804     2.44856     1.415267    13.815570
# min       0.000000     1.000000     0.00000     0.000000     1.300000
# 25%       0.980000     6.500000     0.00000     0.000000    10.800000
# 50%       1.640000     9.500000     1.70000     0.000000    14.160000
# 75%       3.210000    15.000000     2.80000     0.000000    20.300000
# max      36.700000   150.000000    33.20000    24.020000   174.820000
